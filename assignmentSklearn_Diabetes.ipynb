# %%
from sklearn.datasets import load_diabetes
import pandas as pd

# %%
diabetes_dataset=load_diabetes()
diabetes_dataset
type(diabetes_dataset)
# Out:
# sklearn.utils.Bunch

# %%
diabetes_df = pd.DataFrame(diabetes_dataset.data,columns=diabetes_dataset.feature_names)

# %%
diabetes_df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6
# 0 -0.002592  0.019908 -0.017646
# 1 -0.039493 -0.068330 -0.092204
# 2 -0.002592  0.002864 -0.025930
# 3  0.034309  0.022692 -0.009362
# 4 -0.002592 -0.031991 -0.046641

# %%
diabetes_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 442 entries, 0 to 441
# Data columns (total 10 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   age     442 non-null    float64
#  1   sex     442 non-null    float64
#  2   bmi     442 non-null    float64
#  3   bp      442 non-null    float64
#  4   s1      442 non-null    float64
#  5   s2      442 non-null    float64
#  6   s3      442 non-null    float64
#  7   s4      442 non-null    float64
#  8   s5      442 non-null    float64
#  9   s6      442 non-null    float64
# dtypes: float64(10)
# memory usage: 34.7 KB

# %%
    diabetes_df.shape
# Out:
# (442, 10)

# %%
diabetes_df.describe()
# Out:
#                 age           sex           bmi            bp            s1  \
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean  -3.634285e-16  1.308343e-16 -8.045349e-16  1.281655e-16 -8.835316e-17
# std    4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02  4.761905e-02
# min   -1.072256e-01 -4.464164e-02 -9.027530e-02 -1.123996e-01 -1.267807e-01
# 25%   -3.729927e-02 -4.464164e-02 -3.422907e-02 -3.665645e-02 -3.424784e-02
# 50%    5.383060e-03 -4.464164e-02 -7.283766e-03 -5.670611e-03 -4.320866e-03
# 75%    3.807591e-02  5.068012e-02  3.124802e-02  3.564384e-02  2.835801e-02
# max    1.107267e-01  5.068012e-02  1.705552e-01  1.320442e-01  1.539137e-01
#
#                  s2            s3            s4            s5            s6
# count  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02  4.420000e+02
# mean   1.327024e-16 -4.574646e-16  3.777301e-16 -3.830854e-16 -3.412882e-16
# ...

# %%
    diabetes_df.count()
# Out:
# age    442
# sex    442
# bmi    442
# bp     442
# s1     442
# s2     442
# s3     442
# s4     442
# s5     442
# s6     442
# dtype: int64

# %%
diabetes_df.mean()
# Out:
# age   -3.634285e-16
# sex    1.308343e-16
# bmi   -8.045349e-16
# bp     1.281655e-16
# s1    -8.835316e-17
# s2     1.327024e-16
# s3    -4.574646e-16
# s4     3.777301e-16
# s5    -3.830854e-16
# s6    -3.412882e-16
# dtype: float64

# %%
    diabetes_df.columns
# Out:
# Index(['age', 'sex', 'bmi', 'bp', 's1', 's2', 's3', 's4', 's5', 's6'], dtype='object')

# %%
diabetes_df['M1']=diabetes_dataset.target
diabetes_df.head()
# Out:
#      age       sex       bmi        bp        s1        s2        s3  \
# 0  151.0  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1   75.0 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  141.0  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3  206.0 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  135.0 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6     M1
# 0 -0.002592  0.019908 -0.017646  151.0
# 1 -0.039493 -0.068330 -0.092204   75.0
# 2 -0.002592  0.002864 -0.025930  141.0
# 3  0.034309  0.022692 -0.009362  206.0
# 4 -0.002592 -0.031991 -0.046641  135.0

# %%
    diabetes_df.drop(index=0,axis=0)
# Out:
#        age       sex       bmi        bp        s1        s2        s3  \
# 1     75.0 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2    141.0  0.050680  0.044451 -0.005671 -0.045599 -0.034194 -0.032356
# 3    206.0 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    135.0 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5     97.0 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# ..     ...       ...       ...       ...       ...       ...       ...
# 437  178.0  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438  104.0  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  132.0  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440  220.0 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441   57.0 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6     M1
# 1   -0.039493 -0.068330 -0.092204   75.0
# ...

# %%
diabetes_df.drop(index=2,axis=1)
# Out:
#        age       sex       bmi        bp        s1        s2        s3  \
# 0    151.0  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1     75.0 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 3    206.0 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4    135.0 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
# 5     97.0 -0.044642 -0.040696 -0.019442 -0.068991 -0.079288  0.041277
# ..     ...       ...       ...       ...       ...       ...       ...
# 437  178.0  0.050680  0.019662  0.059744 -0.005697 -0.002566 -0.028674
# 438  104.0  0.050680 -0.015906 -0.067642  0.049341  0.079165 -0.028674
# 439  132.0  0.050680 -0.015906  0.017282 -0.037344 -0.013840 -0.024993
# 440  220.0 -0.044642  0.039062  0.001215  0.016318  0.015283 -0.028674
# 441   57.0 -0.044642 -0.073030 -0.081414  0.083740  0.027809  0.173816
#
#            s4        s5        s6     M1
# 0   -0.002592  0.019908 -0.017646  151.0
# ...

# %%
diabetes_df.drop(columns='bp',axis=1)
# Out:
#        age       sex       bmi        s1        s2        s3        s4  \
# 0    151.0  0.050680  0.061696 -0.044223 -0.034821 -0.043401 -0.002592
# 1     75.0 -0.044642 -0.051474 -0.008449 -0.019163  0.074412 -0.039493
# 2    141.0  0.050680  0.044451 -0.045599 -0.034194 -0.032356 -0.002592
# 3    206.0 -0.044642 -0.011595  0.012191  0.024991 -0.036038  0.034309
# 4    135.0 -0.044642 -0.036385  0.003935  0.015596  0.008142 -0.002592
# ..     ...       ...       ...       ...       ...       ...       ...
# 437  178.0  0.050680  0.019662 -0.005697 -0.002566 -0.028674 -0.002592
# 438  104.0  0.050680 -0.015906  0.049341  0.079165 -0.028674  0.034309
# 439  132.0  0.050680 -0.015906 -0.037344 -0.013840 -0.024993 -0.011080
# 440  220.0 -0.044642  0.039062  0.016318  0.015283 -0.028674  0.026560
# 441   57.0 -0.044642 -0.073030  0.083740  0.027809  0.173816 -0.039493
#
#            s5        s6     M1
# 0    0.019908 -0.017646  151.0
# 1   -0.068330 -0.092204   75.0
# ...

# %%
diabetes_df.iloc[2]
# Out:
# age    141.000000
# sex      0.050680
# bmi      0.044451
# bp      -0.005671
# s1      -0.045599
# s2      -0.034194
# s3      -0.032356
# s4      -0.002592
# s5       0.002864
# s6      -0.025930
# M1     141.000000
# Name: 2, dtype: float64

# %%
diabetes_df.iloc[:,0]
# Out:
# 0      151.0
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
#        ...
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# 441     57.0
# Name: age, Length: 442, dtype: float64

# %%
diabetes_df.iloc[:,-1]
# Out:
# 0      151.0
# 1       75.0
# 2      141.0
# 3      206.0
# 4      135.0
#        ...
# 437    178.0
# 438    104.0
# 439    132.0
# 440    220.0
# 441     57.0
# Name: M1, Length: 442, dtype: float64
